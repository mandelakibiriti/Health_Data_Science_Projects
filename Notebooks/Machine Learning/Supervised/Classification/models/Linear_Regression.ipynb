# %%
from IPython.display import Math

# %%
# %%latex
# \[
# \begin{bmatrix}
#     a  &  b      \\
#     c  &  d
# \end{bmatrix}
# =
# \begin{bmatrix}
#     8  &  1      \\
#     7  &  6
# \end{bmatrix}
# \]
# Out:
# \[
# \begin{bmatrix}
#     a  &  b      \\
#     c  &  d
# \end{bmatrix}
# =
# \begin{bmatrix}
#     8  &  1      \\
#     7  &  6
# \end{bmatrix}
# \]
