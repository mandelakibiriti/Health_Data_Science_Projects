# %% [markdown]
# # Exploratory Data Analytics

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Data Types
# There are two basic types of structured data: *numeric and categorical*.
#
# **_Numeric_** data comes in two forms:
# -  **continuous**, such as wind speed or time duration
# -  **discrete** such as the count of the occurrence of an event.
#
# **_Categorical_** data takes only a fixed set of values, such as a type of TV screen (plasma, LCD, LED, etc.) or a state name (Alabama, Alaska, etc.)
# - **Binary** data is an important special case of categorical data that takes on only one of two values, such as 0/1, yes/no, or true
# - **Ordinal** data in which the categories are ordered; an example of this is a numerical rating (1, 2, 3, 4, or 5).

# %% [markdown]
# ### 1.2 Sigma Notation

# %%
from IPython.display import IFrame
IFrame("./pdf/sigma-notation.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./pdf/sigma-notation.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2. Estimates of Location

# %%
from IPython.display import IFrame
IFrame("./pdf/estimates-of-location.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./pdf/estimates-of-location.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 2.1 Mean
# The sum of all values divided by the number of values. Synonym *average*. The **sample mean** $\bar x$ for a set of n values $x_{1}, x_{2}...x_{n}$ is:
#
# $$
# \bar{x} = \Bigg[\frac{\sum \limits ^{n}_{i=1} x_{i} }{n}\Bigg]
# $$
#
# From a population perspective: The **population mean**, $\mu$, is the average of all population values, $\mu = (\sum \limits ^{N}_{i=1})/N$, for a finite population of size N.
#
# #### Trimmed mean
# The average of all values after dropping a fixed number of extreme values. Synonym *truncated mean*. Representing the sorted values by $x_{(1)}, x_{(2)},..., x_{(n)}$ where $x_{(1)}$ is the smallest value and $x_{(n)}$ the largest, the formula to compute the trimmed mean with *p* smallest and largest values omitted is:
#
# $$
# \bar{x} = \Bigg[ \frac{\sum \limits ^{n-p}_{i = p + 1} x_{(i)}}{n - 2p} \Bigg]
# $$
#
# #### Weighted mean
# The sum of all values times a weight divided by the sum of the weights. Synonym *weighted average* The weight that is used here is the frequency of that number in a set.
#
# $$
# \bar{x}_w = \Bigg[ \frac{\sum \limits ^{n}_{i=1} w_{i}x_{i}}{\sum \limits ^{n}_{i=1} w_{i}}  \Bigg]
# $$
#
# #### Geometric Mean
# The geometric mean is often used for a set of numbers whose values are meant to be multiplied together or are exponential in nature, such as a set of growth figures: values of the human population or interest rates of a financial investment over time. It also applies to benchmarking, where it is particularly useful for computing means of speedup ratios: since the mean of 0.5x (half as fast) and 2x (twice as fast) will be 1 (i.e., no speedup overall).
# $$
# \prod \limits ^{n}_{i=1} \alpha_i = {\sqrt[{n}]{a_{1}a_{2}a_{3}\cdots a_{n}}}
# $$
#
# #### Harmonic Mean
# It is sometimes appropriate for situations when the average rate is desired. The harmonic mean H of the positive real numbers ${x_{1},x_{2} \cdots x_{n}}$ is defined to be:
#
# $$
# {H(x_{1},x_{2},\ldots ,x_{n})={\frac {n}{{\frac {1}{x_{1}}}+{\frac {1}{x_{2}}}+\cdots +{\frac {1}{x_{n}}}}}={\frac {n}{\sum _{i=1}^{n}{\frac {1}{x_{i}}}}}.}
# $$

# %% [markdown]
# ### 2.1.1 Examples

# %% [markdown]
# #### 2.1.1.1 Trimmed Mean Example

# %%
from IPython.display import IFrame
IFrame("./pdf/trimmed-mean.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./pdf/trimmed-mean.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### 2.1.1.2 Weighted Mean

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("LdrBNhWw9AM", width=1000, height=500)

# %% [markdown]
# #### 2.1.1.3 Geometric Mean example
# Suppose for example a person invests 1000 dollars in shares and achieves annual returns of +10%, -12%, +90%, -30% and +25% over 5 consecutive years to give a final investment value of 1,609 dollars. The arithmetic mean of the annual percent changes is 16.6%. However, this value is unrepresentative. If the initial investment grew by 16.6% per annum, it would be worth 2155 dollars after 5 years. In fact, to find the average percentage growth it is necessary compute the geometric mean of the successive annual growth ratios (1.1, 0.88, 1.9, 0.7, 1.25). This gives a value of 1.0998 which corresponds to an annual average growth of 9.98%. It can be readily verified that an investment of 1000 dollars which grows by 9.98% over five years would achieve a final investment value of 1,609 dollars. In this case, the geometric mean is appropriate because investment growth is multiplicative rather than additive.

# %% [markdown]
# ### 2.2 Median
# The value such that one-half of the data lies above and below. Synonym *50th percentile* The **sample median $\tilde{x}$** is referred to as a robust estimate of location since it is not influenced by
# outliers (extreme cases) that could skew the results
#
# $$ \tilde{x} = \Bigg \{{X[\frac{n+1}{2}]\textrm{ if n is odd}} $$
#
# $$ \tilde{x} = \Bigg \{{X[\frac{n}{2}] + {X[\frac{n}{2}+1}]\textrm{ if n is even}} $$
#
# ### Weighted median
# The value such that one-half of the sum of the weights lies above and below the sorted data.
#
# The weight is the frequency of that number in a set and the weight amounts to 1.
#
# $$
# \sum \limits^{n}_{i=1}w_{i} = 1
# $$
#
#
# In weighted median you sort the values in descending order. Add up the weights for the values in order (i.e. a running sum of weight) Find the value associated with the weight whose running sum crosses 50% of the total weigh An explanation can be found [here](https://www.datablick.com/blog/2017/7/3/weighted-medians-for-weighted-data-in-tableau).
#
# The weighted median is the element $x_{k}$ satisfying:
#
# $$
# \textrm{a. Lower Weighted Median: } \sum \limits ^{k-1}_{i=1} < 1/2 \textrm{ and} \sum \limits ^{n}_{i=k+1} = 1/2
# $$
#
# $$
# \textrm{b. Upper Weighted Median: } \sum \limits ^{k-1}_{i=1} = 1/2 \textrm{ and} \sum \limits ^{n}_{i=k+1} < 1/2
# $$
#
# Examples of the use of weighted median can be found [here](https://en.wikipedia.org/wiki/Weighted_median#Examples)
# ### Percentile
# The value such that *P* percent of the data lies below. Synonym *quantile*
#
# ### Outlier
# A data value that is very different from most of the data. Synonym *extreme value*

# %% [markdown]
# ### Mean Squared Error (MSE)
# Mean Squared Error (MSE) is a critical metric for evaluating the performance of predictive models, particularly in regression analysis. In the example provided, MSE indicates high performance through several key factors:
#
# ![image.png](attachment:image.png)
#
# 1. **Definition and Calculation**: MSE measures the average of the squared differences between predicted values and actual target values. It is calculated using the formula:
#
#    $$
#    \text{MSE} = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
#    $$
#    where $y_i$ represents the actual values, $\hat{y}_i$ are the predicted values, and $n$ is the number of observations.
#
# 3. **Sensitivity to Errors**: By squaring the differences, MSE places greater emphasis on larger errors. This means that significant deviations from actual values will disproportionately affect MSE, making it a sensitive measure of model accuracy. A lower MSE indicates that predictions are closer to true values, reflecting better overall model performance.
#
# 4. **Interpretation of Values**: In the context of the example, a high MSE (e.g., >300,000 for the dummy model) suggests poor predictive capability since it indicates that predictions are far from actual outcomes. Conversely, a low MSE (close to 0 for the proper model) signifies that the model accurately captures the underlying relationship between features and target variables, demonstrating effective learning and fitting to the data.
#
# 5. **Performance Benchmark**: MSE serves as a benchmark for comparing different models. A model with a significantly lower MSE than others indicates superior predictive power and is generally preferred in practice. In this case, comparing a dummy model with an MSE of >300,000 against a properly fitted model with an MSE close to 0 highlights the effectiveness of fitting processes in machine learning.
#
# 6. **Practical Implications**: The practical implication of achieving a low MSE is that it leads to more reliable predictions in real-world applications, thus enhancing decision-making based on those predictions. This reliability is crucial across various domains, from finance to healthcare.
#
# In summary, MSE is an essential indicator of model performance; lower values signify better fitting and prediction accuracy, while higher values indicate significant errors and poor model performance.
#
# Citations:
# [1] https://encord.com/glossary/mean-square-error-mse/
