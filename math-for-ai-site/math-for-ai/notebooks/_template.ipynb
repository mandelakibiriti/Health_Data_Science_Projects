# %% [markdown]
# # Week NN — Title
#
# **Chapters:** …
# **Build goal:** one sentence.
#
# Rules: NumPy and Matplotlib only. Every function you write gets checked against a library implementation or a finite-difference / brute-force version.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)

# %% [markdown]
# ## 1. Implement

# %%
# your implementation here

# %% [markdown]
# ## 2. Check
#
# Compare against NumPy / SciPy / a brute-force computation.

# %%
# assert np.allclose(mine, reference)

# %% [markdown]
# ## 3. Where it lives in AI
#
# Two or three sentences, in your own words, on what this week's mathematics does inside a model.
